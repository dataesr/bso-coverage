# %%
from dotenv import load_dotenv
import os
import json
import re
import requests
from retry import retry
import duckdb
import pandas as pd
import bso_coverage_tools as bct
import mercury

# %%
# Collect all French publications in OpenAlex
def reduce_french_openalex(openalex_files, yearmin = 2018, yearmax = 2023):
    publications_fr = []
    for file in openalex_files:
        with open(f"data/openalex/{file}.jsonl") as f:
            # Iterate over json lines
            for line in f:

                # Get publication
                publication = json.loads(line)

                # Check dates
                publication_year = publication.get("publication_year")
                if publication_year is None or publication_year < yearmin or publication_year > yearmax:
                    continue
                
                # Check paratext
                is_paratext = publication.get("is_paratext")
                if is_paratext:
                    continue
            
                
                # Check if french publication
                if "authorships" in publication:
                    countries = []
                    institutions = []
                    for authorship in publication.get("authorships"):
                        countries += authorship.get("countries")
                        if len(authorship.get("institutions")):
                            institutions += [authorship.get("institutions")[0].get("display_name")]

                    if "FR" in countries:
                        # Primary location
                        primary_location = None
                        if "primary_location" in publication:
                            if publication.get("primary_location") is not None:
                                if "source" in publication.get("primary_location"):
                                    if publication.get("primary_location").get("source") is not None:
                                        primary_location = publication.get("primary_location").get("source").get("display_name")
                        
                        # Check coverage
                        coverage_last_state = None
                        coverage_last_error = None
                        coverage_last_error_data = None
                        if publication.get("doi") is not None:
                             coverage = bct.analyse_from_openalex_work(publication, cli=False, as_pandas=False)
                             if coverage is not None:
                                coverage_last_state = coverage.get("last_state")
                                coverage_last_error = coverage.get("last_error")
                                coverage_last_error_data = coverage.get("last_error_data")
                    
                        # Publication data
                        data = {
                            "id": publication.get("id"),
                            "doi": publication.get("doi"),
                            "year": publication.get("publication_year"),
                            "type": publication.get("type"),
                            "type_crossref": publication.get("type_crossref"),
                            "institutions": list(set(institutions)),
                            "countries": list(set(countries)),
                            "primary_location": primary_location,
                            "is_oa": publication.get("open_access").get("is_oa") if "open_access" in publication else None,
                            "coverage": {"last_state": coverage_last_state, "last_error": coverage_last_error, "last_error_data": coverage_last_error_data}
                        }
                        # Add to list of publications
                        publications_fr.append(data)
                
    return publications_fr

# %%
# Collect all French publications in OpenAlex
def collect_french_openalex(openalex_files, con, startindex = 0, yearmin = 2018, yearmax = 2023, forcebreak=False):
    publications_fr = []
    for file in openalex_files:
        with open(f"data/openalex/{file}.jsonl") as f:
            index = -1
            # Iterate over json lines
            for line in f:
                index +=1
                if index < startindex:
                    continue
                
                # Get publication
                publication = json.loads(line)

                # Check dates
                publication_year = publication.get("publication_year")
                if publication_year is None or publication_year < yearmin or publication_year > yearmax:
                    continue
                
                # Check if french publication
                if "authorships" in publication:
                    countries = []
                    for authorship in publication.get("authorships"):
                        countries += authorship.get("countries")

                    if "FR" in countries:
                        # Get relevant data 
                        print(f"{publication.get('id')}: french publication detected")
                        data = {
                            "id": publication.get("id"),
                            "doi": publication.get("doi"),
                            "year": publication_year,
                            "type": publication.get("type"),
                            "coverage": bct.analyse_from_openalex_work(publication, cli=False, as_pandas=False) if publication.get("doi") else {"doi": publication.get("doi"), "last_state": None, "last_error": None, "last_error_data": None}
                        }
                        df = pd.json_normalize(data)
                        # print("data", data)
                        
                        # Add publication to duckdb
                        if not con.query(f"SELECT * FROM openalex_fr WHERE id = '{data.get('id')}'"):
                            print(f"added index {index}")
                            con.sql("INSERT INTO openalex_fr SELECT * FROM df")
                
                if forcebreak:
                    break

# %%
# Get french publications
publications_fr = reduce_french_openalex(["part_012"])

# %%
# Export to parquet
print("Number of publications", len(publications_fr))
print(publications_fr[0])
publications_df = pd.json_normalize(publications_fr)
publications_df["coverage.last_error_data"] = publications_df["coverage.last_error_data"].astype(str)
display(publications_df.head(2))
publications_df.to_parquet("data/openalex/part_012.parquet")
# Out:
# Number of publications 5180
# {'id': 'https://openalex.org/W2968185027', 'doi': 'https://doi.org/10.1103/physrevb.100.060401', 'year': 2019, 'type': 'article', 'type_crossref': 'journal-article', 'institutions': ['Université de Lorraine', 'Institute for High Pressure Physics', 'Institut Laue-Langevin', 'Laboratoire Léon Brillouin'], 'countries': ['FR', 'RU'], 'primary_location': 'Physical review', 'is_oa': True, 'coverage': {'last_state': 'IN_FOSM_FR', 'last_error': 'MISMATCH_TYPE', 'last_error_data': ('journal-article', 'article')}}
#                                  id  \
# 0  https://openalex.org/W2968185027
# 1  https://openalex.org/W2968592665
#
#                                            doi  year     type  \
# 0  https://doi.org/10.1103/physrevb.100.060401  2019  article
# 1            https://doi.org/10.2514/1.c035343  2019  article
#
#      type_crossref                                       institutions  \
# 0  journal-article  [Université de Lorraine, Institute for High Pr...
# 1  journal-article      [University of Paris-Saclay, Safran (France)]
#
#   countries     primary_location  is_oa coverage.last_state  \
# 0  [FR, RU]      Physical review   True          IN_FOSM_FR
# 1      [FR]  Journal of Aircraft   True          IN_FOSM_FR
#
#   coverage.last_error        coverage.last_error_data
# 0       MISMATCH_TYPE  ('journal-article', 'article')
# 1       MISMATCH_TYPE  ('journal-article', 'article')

# %%
with duckdb.connect("bso_coverage.db") as con:
    con.sql("DROP TABLE openalex_fr")
# Out:
# ---------------------------------------------------------------------------
# CatalogException                          Traceback (most recent call last)
# c:\Users\vbarbier\MESR\bso-coverage\1_openalex_database.ipynb Cell 6 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/vbarbier/MESR/bso-coverage/1_openalex_database.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> with duckdb.connect("bso_coverage.db") as con:
#       <a href='vscode-notebook-cell:/c%3A/Users/vbarbier/MESR/bso-coverage/1_openalex_database.ipynb#X16sZmlsZQ%3D%3D?line=1'>2</a>     con.sql("DROP TABLE openalex_fr")
#
# c:\Users\vbarbier\MESR\bso-coverage\1_openalex_database.ipynb Cell 6 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/vbarbier/MESR/bso-coverage/1_openalex_database.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> with duckdb.connect("bso_coverage.db") as con:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/vbarbier/MESR/bso-coverage/1_openalex_database.ipynb#X16sZmlsZQ%3D%3D?line=1'>2</a>     con.sql("DROP TABLE openalex_fr")
#
# CatalogException: Catalog Error: Table with name openalex_fr does not exist!
# Did you mean "openalex"?

# %%
files = ["part_000"]
with duckdb.connect("bso_coverage.db") as con:
    collect_french_openalex(files, con, startindex=67026, forcebreak=False)
# Out:
# https://openalex.org/W2799933121: french publication detected
# https://openalex.org/W2883916703: french publication detected
# added index 67030
# https://openalex.org/W2905736690: french publication detected
# added index 67039
# https://openalex.org/W2919006054: french publication detected
# added index 67042
# https://openalex.org/W2941313896: french publication detected
# added index 67044
# https://openalex.org/W2947520615: french publication detected
# added index 67461
# https://openalex.org/W2961319233: french publication detected
# added index 67464
# https://openalex.org/W2997720498: french publication detected
# added index 67465
# https://openalex.org/W3103215654: french publication detected
# added index 67472
# https://openalex.org/W2945715301: french publication detected
# added index 67855
# https://openalex.org/W2789389013: french publication detected
# added index 68237
# https://openalex.org/W2884149298: french publication detected
# added index 68243
# https://openalex.org/W3008170328: french publication detected
# added index 68258
# https://openalex.org/W3103618496: french publication detected
# added index 68262
# https://openalex.org/W2777349738: french publication detected
# added index 68682
# https://openalex.org/W2788997417: french publication detected
# added index 68684
# https://openalex.org/W2800319132: french publication detected
# added index 68687
# https://openalex.org/W2808069317: french publication detected
# added index 68688
# https://openalex.org/W2951817901: french publication detected
# added index 68697
# https://openalex.org/W2993526648: french publication detected
# added index 68700
# https://openalex.org/W3038412545: french publication detected
# added index 68708
# https://openalex.org/W3127209431: french publication detected
# added index 68712
# https://openalex.org/W3180006770: french publication detected
# added index 68714
# https://openalex.org/W2797515701: french publication detected
# added index 69101
# https://openalex.org/W3043781331: french publication detected
# added index 69127
# https://openalex.org/W3095638759: french publication detected
# added index 69130
# https://openalex.org/W2898510820: french publication detected
# added index 69539
# https://openalex.org/W2923683745: french publication detected
# added index 69544
# https://openalex.org/W2974545220: french publication detected
# added index 69548
# https://openalex.org/W2976599382: french publication detected
# added index 69549
# https://openalex.org/W3011518560: french publication detected
# added index 69556
# https://openalex.org/W3106389093: french publication detected
# added index 69559
# https://openalex.org/W2775177930: french publication detected
# added index 69905
# https://openalex.org/W2930968622: french publication detected
# added index 69920
# https://openalex.org/W3015361084: french publication detected
# added index 69931
# https://openalex.org/W4225610241: french publication detected
# added index 69945
# https://openalex.org/W2748094183: french publication detected
# added index 70323
# https://openalex.org/W2794164629: french publication detected
# added index 70327
# https://openalex.org/W2922176752: french publication detected
# added index 70336
# https://openalex.org/W2924743030: french publication detected
# added index 70337
# https://openalex.org/W2956696709: french publication detected
# added index 70342
# https://openalex.org/W3022258762: french publication detected
# added index 70345
# https://openalex.org/W3025889651: french publication detected
# added index 70346
# https://openalex.org/W3016774956: french publication detected
# added index 70782
# https://openalex.org/W3081916995: french publication detected
# added index 70788
# https://openalex.org/W3043538464: french publication detected
# added index 71182
# https://openalex.org/W3119649652: french publication detected
# added index 71193
# https://openalex.org/W3156859314: french publication detected
# added index 71198
# https://openalex.org/W2787246109: french publication detected
# added index 71626
# https://openalex.org/W2900106581: french publication detected
# added index 71639
# https://openalex.org/W2938912239: french publication detected
# added index 71644
# https://openalex.org/W2742012545: french publication detected
# added index 72066
# https://openalex.org/W2901506506: french publication detected
# added index 72081
# https://openalex.org/W2915363558: french publication detected
# added index 72087
# https://openalex.org/W4226317263: french publication detected
# added index 72113
# https://openalex.org/W2761321759: french publication detected
# added index 72512
# https://openalex.org/W2901041673: french publication detected
# added index 72521
# https://openalex.org/W3030407925: french publication detected
# added index 72537
# https://openalex.org/W4308697725: french publication detected
# added index 72556
# https://openalex.org/W2998909275: french publication detected
# added index 72942
# https://openalex.org/W3014418260: french publication detected
# added index 72947
# https://openalex.org/W2971477701: french publication detected
# added index 73391
# https://openalex.org/W3015355998: french publication detected
# added index 73398
# https://openalex.org/W3128934913: french publication detected
# added index 73408
# https://openalex.org/W2912656789: french publication detected
# added index 73820
# https://openalex.org/W2920801774: french publication detected
# added index 73823
# https://openalex.org/W2802575142: french publication detected
# added index 74274
# https://openalex.org/W2891543930: french publication detected
# added index 74283
# https://openalex.org/W2905059551: french publication detected
# added index 74287
# https://openalex.org/W2781993955: french publication detected
# added index 74747
# https://openalex.org/W2913484031: french publication detected
# added index 74760
# https://openalex.org/W2953495640: french publication detected
# added index 74769
# https://openalex.org/W2988778168: french publication detected
# added index 74772
# https://openalex.org/W2989608901: french publication detected
# added index 74773
# https://openalex.org/W3115151307: french publication detected
# added index 74791
# https://openalex.org/W3040937184: french publication detected
# added index 75255
# https://openalex.org/W2890624098: french publication detected
# added index 75748
# https://openalex.org/W2903232633: french publication detected
# added index 75753
# https://openalex.org/W2946385297: french publication detected
# added index 75759
# https://openalex.org/W3031924236: french publication detected
# added index 75769
# https://openalex.org/W3134181354: french publication detected
# added index 76276
# https://openalex.org/W3142845014: french publication detected
# added index 76278
# https://openalex.org/W2793807243: french publication detected
# added index 76764
# https://openalex.org/W2907470641: french publication detected
# added index 76772
# https://openalex.org/W2945116772: french publication detected
# added index 76779
# https://openalex.org/W3020578014: french publication detected
# added index 76791
# https://openalex.org/W3046581697: french publication detected
# added index 76794
# https://openalex.org/W3086258129: french publication detected
# added index 76796
# https://openalex.org/W3207086349: french publication detected
# added index 76806
# https://openalex.org/W2896268397: french publication detected
# added index 77287
# https://openalex.org/W3018057581: french publication detected
# added index 77308
# https://openalex.org/W3026232934: french publication detected
# added index 77309
# https://openalex.org/W2735943180: french publication detected
# added index 77795
# https://openalex.org/W2898617434: french publication detected
# added index 77820
# https://openalex.org/W2849537270: french publication detected
# added index 78307
# https://openalex.org/W2911601413: french publication detected
# added index 78315
# https://openalex.org/W2952542446: french publication detected
# added index 78321
# https://openalex.org/W3022757978: french publication detected
# added index 78327
# https://openalex.org/W3106489981: french publication detected
# added index 78335
# https://openalex.org/W3123003847: french publication detected
# added index 78338
# https://openalex.org/W2906516989: french publication detected
# added index 78844
# https://openalex.org/W2914225706: french publication detected
# added index 78846
# https://openalex.org/W2899346938: french publication detected
# added index 79376
# https://openalex.org/W2901929987: french publication detected
# added index 79377
# https://openalex.org/W2906821085: french publication detected
# added index 79378
# https://openalex.org/W2980595867: french publication detected
# added index 79392
# https://openalex.org/W2770229938: french publication detected
# added index 79876
# https://openalex.org/W2866507047: french publication detected
# added index 79883
# https://openalex.org/W2897607471: french publication detected
# added index 79887
# https://openalex.org/W2934055254: french publication detected
# added index 79894
# https://openalex.org/W4223510971: french publication detected
# added index 79922
# https://openalex.org/W2793453599: french publication detected
# added index 80393
# https://openalex.org/W3003881918: french publication detected
# added index 80410
# https://openalex.org/W3024294833: french publication detected
# added index 80416
# https://openalex.org/W3105775294: french publication detected
# added index 80427
# https://openalex.org/W3171491383: french publication detected
# added index 80433
# https://openalex.org/W1563635490: french publication detected
# added index 80475
# https://openalex.org/W2784426771: french publication detected
# added index 80947
# https://openalex.org/W2792010672: french publication detected
# added index 80948
# https://openalex.org/W2897890026: french publication detected
# added index 80958
# https://openalex.org/W2946284807: french publication detected
# added index 80964
# https://openalex.org/W3113344283: french publication detected
# added index 80983
# https://openalex.org/W3116473131: french publication detected
# added index 80984
# https://openalex.org/W3122570896: french publication detected
# added index 80985
# https://openalex.org/W3181205698: french publication detected
# added index 80990
# https://openalex.org/W2798187866: french publication detected
# added index 81499
# https://openalex.org/W2983947643: french publication detected
# added index 81520
# https://openalex.org/W3011016572: french publication detected
# added index 81523
# https://openalex.org/W3114973248: french publication detected
# added index 81533
# https://openalex.org/W3178692152: french publication detected
# added index 81543
# https://openalex.org/W3181568850: french publication detected
# added index 82085
# https://openalex.org/W2802395419: french publication detected
# added index 82620
# https://openalex.org/W2981598129: french publication detected
# added index 82637
# https://openalex.org/W2989421973: french publication detected
# added index 82640
# https://openalex.org/W3017202750: french publication detected
# added index 82643
# https://openalex.org/W3091842322: french publication detected
# added index 82650
# https://openalex.org/W3195674796: french publication detected
# added index 82658
# https://openalex.org/W2995681102: french publication detected
# added index 83198
# https://openalex.org/W3012498554: french publication detected
# added index 83200
# https://openalex.org/W2889325185: french publication detected
# added index 83753
# https://openalex.org/W2915708315: french publication detected
# added index 83760
# https://openalex.org/W2969722774: french publication detected
# added index 83773
# https://openalex.org/W2805980535: french publication detected
# added index 84355
# https://openalex.org/W2902758299: french publication detected
# added index 84364
# https://openalex.org/W2968989098: french publication detected
# added index 84373
# https://openalex.org/W3021565497: french publication detected
# added index 84380
# https://openalex.org/W3057728496: french publication detected
# added index 84387
# https://openalex.org/W3096478584: french publication detected
# added index 84389
# https://openalex.org/W3160372581: french publication detected
# added index 84399
# https://openalex.org/W2790544943: french publication detected
# added index 84917
# https://openalex.org/W2885579027: french publication detected
# added index 84926
# https://openalex.org/W2897793560: french publication detected
# added index 84929
# https://openalex.org/W2962981403: french publication detected
# added index 84940
# https://openalex.org/W3005921056: french publication detected
# added index 84948
# https://openalex.org/W3092347758: french publication detected
# added index 84955
# https://openalex.org/W3111815510: french publication detected
# added index 84962
# https://openalex.org/W2781482422: french publication detected
# added index 85497
# https://openalex.org/W2788733497: french publication detected
# added index 85501
# https://openalex.org/W2920860000: french publication detected
# added index 85512
# https://openalex.org/W3013383466: french publication detected
# added index 85525
# https://openalex.org/W3037377642: french publication detected
# added index 85529
# https://openalex.org/W3037959220: french publication detected
# added index 85530
# https://openalex.org/W3082456432: french publication detected
# added index 85531
# https://openalex.org/W2914713473: french publication detected
# added index 86055
# https://openalex.org/W3003942949: french publication detected
# added index 86067
# https://openalex.org/W3015727970: french publication detected
# added index 86071
# https://openalex.org/W2981612066: french publication detected
# added index 86677
# https://openalex.org/W2923719451: french publication detected
# added index 87267
# https://openalex.org/W3039739427: french publication detected
# added index 87289
# https://openalex.org/W2808186163: french publication detected
# added index 87902
# https://openalex.org/W2808355995: french publication detected
# added index 87903
# https://openalex.org/W2993089090: french publication detected
# added index 87927
# https://openalex.org/W2789518032: french publication detected
# added index 88517
# https://openalex.org/W2806435360: french publication detected
# added index 88527
# https://openalex.org/W2895137021: french publication detected
# added index 88534
# https://openalex.org/W2898458682: french publication detected
# added index 88537
# https://openalex.org/W2979186211: french publication detected
# added index 88546
# https://openalex.org/W3002684299: french publication detected
# added index 88551
# https://openalex.org/W3035459951: french publication detected
# added index 88561
# https://openalex.org/W2786988971: french publication detected
# added index 89168
# https://openalex.org/W2795397383: french publication detected
# added index 89172
# https://openalex.org/W2886399855: french publication detected
# added index 89174
# https://openalex.org/W2925110565: french publication detected
# added index 89181
# https://openalex.org/W3015563505: french publication detected
# added index 89195
# https://openalex.org/W3042072141: french publication detected
# added index 89203
# https://openalex.org/W3060960901: french publication detected
# added index 89204
# https://openalex.org/W3166756865: french publication detected
# added index 89218
# https://openalex.org/W4220970752: french publication detected
# added index 89221
# https://openalex.org/W2770987362: french publication detected
# added index 89843
# https://openalex.org/W2883729505: french publication detected
# added index 89857
# https://openalex.org/W2904314782: french publication detected
# added index 89859
# https://openalex.org/W2967683178: french publication detected
# added index 89874
# https://openalex.org/W2974267385: french publication detected
# added index 89876
# https://openalex.org/W3007562574: french publication detected
# added index 89884
# https://openalex.org/W3080176159: french publication detected
# added index 89891
# https://openalex.org/W3089730087: french publication detected
# added index 89893
# https://openalex.org/W2765506441: french publication detected
# added index 90483
# https://openalex.org/W2809036207: french publication detected
# added index 90495
# https://openalex.org/W2897171941: french publication detected
# added index 90504
# https://openalex.org/W2990377810: french publication detected
# added index 90521
# https://openalex.org/W3048946657: french publication detected
# added index 90531
# https://openalex.org/W3105904302: french publication detected
# added index 90535
# https://openalex.org/W4226441491: french publication detected
# added index 90554
# https://openalex.org/W2774825032: french publication detected
# added index 91165
# https://openalex.org/W2807966166: french publication detected
# added index 91174
# https://openalex.org/W3099826393: french publication detected
# added index 91209
# https://openalex.org/W3110814768: french publication detected
# added index 91216
# https://openalex.org/W2788689621: french publication detected
# added index 91804
# https://openalex.org/W2797685139: french publication detected
# added index 91809
# https://openalex.org/W2891385015: french publication detected
# added index 91819
# https://openalex.org/W2981577557: french publication detected
# added index 91841
# https://openalex.org/W3101599961: french publication detected
# added index 91861
# https://openalex.org/W3111125496: french publication detected
# added index 91864
# https://openalex.org/W3193614870: french publication detected
# ---------------------------------------------------------------------------
# HTTPClientError                           Traceback (most recent call last)
# File c:\Users\vbarbier\AppData\Local\Programs\Python\Python311\Lib\site-packages\keystoneclient\v3\client.py:343, in Client.get_raw_token_from_identity_service(self, auth_url, user_id, username, user_domain_id, user_domain_name, password, domain_id, domain_name, project_id, project_name, project_domain_id, project_domain_name, token, trust_id, **kwargs)
#     334     plugin = v3_auth.Auth(auth_url, auth_methods,
#     335                           trust_id=trust_id,
#     336                           domain_id=domain_id,
#    (...)
#     340                           project_domain_id=project_domain_id,
#     341                           project_domain_name=project_domain_name)
# --> 343     return plugin.get_auth_ref(self.session)
#     344 except (exceptions.AuthorizationFailure, exceptions.Unauthorized):
#
# File c:\Users\vbarbier\AppData\Local\Programs\Python\Python311\Lib\site-packages\keystoneclient\auth\identity\v3\base.py:188, in Auth.get_auth_ref(self, session, **kwargs)
#     187 _logger.debug('Making authentication request to %s', token_url)
# --> 188 resp = session.post(token_url, json=body, headers=headers,
#     189                     authenticated=False, log=False, **rkwargs)
#     191 try:
#
# File c:\Users\vbarbier\AppData\Local\Programs\Python\Python311\Lib\site-packages\keystoneclient\session.py:543, in Session.post(self, url, **kwargs)
#     538 """Perform a POST request.
#     539
#     540 This calls :py:meth:`.request()` with ``method`` set to ``POST``.
#     541
#     542 """
# --> 543 return self.request(url, 'POST', **kwargs)
#
# File c:\Users\vbarbier\AppData\Local\Programs\Python\Python311\Lib\site-packages\keystoneclient\session.py:443, in Session.request(self, url, method, json, original_ip, user_agent, redirect, authenticated, endpoint_filter, auth, requests_auth, raise_exc, allow_reauth, log, endpoint_override, connect_retries, logger, **kwargs)
#     441     logger.debug('Request returned failure status: %s',
#     442                  resp.status_code)
# --> 443     raise exceptions.from_response(resp, method, url)
#     445 return resp
#
# HTTPClientError: HTTP Client Error (HTTP 429)
#
# During handling of the above exception, another exception occurred:
#
# AuthorizationFailure                      Traceback (most recent call last)
# File c:\Users\vbarbier\AppData\Local\Programs\Python\Python311\Lib\site-packages\swiftclient\client.py:619, in get_auth_keystone(auth_url, user, key, os_options, **kwargs)
#     618 try:
# --> 619     _ksclient = ksclient.Client(
#     620         username=user,
#     621         password=key,
#     622         token=os_options.get('auth_token'),
#     623         tenant_name=os_options.get('tenant_name'),
#     624         tenant_id=os_options.get('tenant_id'),
#     625         user_id=os_options.get('user_id'),
#     626         user_domain_name=os_options.get('user_domain_name'),
#     627         user_domain_id=os_options.get('user_domain_id'),
#     628         project_name=os_options.get('project_name'),
#     629         project_id=os_options.get('project_id'),
#     630         project_domain_name=os_options.get('project_domain_name'),
#     631         project_domain_id=os_options.get('project_domain_id'),
#     632         debug=debug,
#     633         cacert=kwargs.get('cacert'),
#     634         cert=kwargs.get('cert'),
#     635         key=kwargs.get('cert_key'),
#     636         auth_url=auth_url, insecure=insecure, timeout=timeout)
#     637 except ksexceptions.Unauthorized:
#
# File c:\Users\vbarbier\AppData\Local\Programs\Python\Python311\Lib\site-packages\keystoneclient\v3\client.py:267, in Client.__init__(self, **kwargs)
#     266 if 'session' not in kwargs and self.management_url is None:
# --> 267     self.authenticate()
#
# File c:\Users\vbarbier\AppData\Local\Programs\Python\Python311\Lib\site-packages\keystoneclient\httpclient.py:583, in HTTPClient.authenticate(self, username, password, tenant_name, tenant_id, auth_url, token, user_id, domain_name, domain_id, project_name, project_id, user_domain_id, user_domain_name, project_domain_id, project_domain_name, trust_id, region_name)
#     582 kwargs['password'] = password
# --> 583 resp = self.get_raw_token_from_identity_service(**kwargs)
#     585 if isinstance(resp, access.AccessInfo):
#
# File c:\Users\vbarbier\AppData\Local\Programs\Python\Python311\Lib\site-packages\keystoneclient\v3\client.py:352, in Client.get_raw_token_from_identity_service(self, auth_url, user_id, username, user_domain_id, user_domain_name, password, domain_id, domain_name, project_id, project_name, project_domain_id, project_domain_name, token, trust_id, **kwargs)
#     351 except Exception as e:
# --> 352     raise exceptions.AuthorizationFailure(
#     353         _('Authorization failed: %s') % e)
#
# AuthorizationFailure: Authorization failed: HTTP Client Error (HTTP 429)
#
# During handling of the above exception, another exception occurred:
#
# ClientException                           Traceback (most recent call last)
# c:\Users\vbarbier\MESR\bso-coverage\1_openalex_database.ipynb Cell 3 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/vbarbier/MESR/bso-coverage/1_openalex_database.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> files = ["part_000"]
# ----> <a href='vscode-notebook-cell:/c%3A/Users/vbarbier/MESR/bso-coverage/1_openalex_database.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> with duckdb.connect("bso_coverage.db") as con:
#       <a href='vscode-notebook-cell:/c%3A/Users/vbarbier/MESR/bso-coverage/1_openalex_database.ipynb#X12sZmlsZQ%3D%3D?line=2'>3</a>     collect_french_openalex(files, con, startindex=67026, forcebreak=False)
#
# c:\Users\vbarbier\MESR\bso-coverage\1_openalex_database.ipynb Cell 3 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/vbarbier/MESR/bso-coverage/1_openalex_database.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> files = ["part_000"]
#       <a href='vscode-notebook-cell:/c%3A/Users/vbarbier/MESR/bso-coverage/1_openalex_database.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> with duckdb.connect("bso_coverage.db") as con:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/vbarbier/MESR/bso-coverage/1_openalex_database.ipynb#X12sZmlsZQ%3D%3D?line=2'>3</a>     collect_french_openalex(files, con, startindex=67026, forcebreak=False)
#
# c:\Users\vbarbier\MESR\bso-coverage\1_openalex_database.ipynb Cell 3 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/vbarbier/MESR/bso-coverage/1_openalex_database.ipynb#X12sZmlsZQ%3D%3D?line=25'>26</a> if "FR" in countries:
#      <a href='vscode-notebook-cell:/c%3A/Users/vbarbier/MESR/bso-coverage/1_openalex_database.ipynb#X12sZmlsZQ%3D%3D?line=26'>27</a>     # Get relevant data
#      <a href='vscode-notebook-cell:/c%3A/Users/vbarbier/MESR/bso-coverage/1_openalex_database.ipynb#X12sZmlsZQ%3D%3D?line=27'>28</a>     print(f"{publication.get('id')}: french publication detected")
#      <a href='vscode-notebook-cell:/c%3A/Users/vbarbier/MESR/bso-coverage/1_openalex_database.ipynb#X12sZmlsZQ%3D%3D?line=28'>29</a>     data = {
#      <a href='vscode-notebook-cell:/c%3A/Users/vbarbier/MESR/bso-coverage/1_openalex_database.ipynb#X12sZmlsZQ%3D%3D?line=29'>30</a>         "id": publication.get("id"),
#      <a href='vscode-notebook-cell:/c%3A/Users/vbarbier/MESR/bso-coverage/1_openalex_database.ipynb#X12sZmlsZQ%3D%3D?line=30'>31</a>         "doi": publication.get("doi"),
# ---> <a href='vscode-notebook-cell:/c%3A/Users/vbarbier/MESR/bso-coverage/1_openalex_database.ipynb#X12sZmlsZQ%3D%3D?line=31'>32</a>         "coverage": bct.analyse_from_openalex_work(publication, cli=False, as_pandas=False) if publication.get("doi") else {"doi": publication.get("doi"), "last_state": None, "last_error": None, "last_error_data": None}
#      <a href='vscode-notebook-cell:/c%3A/Users/vbarbier/MESR/bso-coverage/1_openalex_database.ipynb#X12sZmlsZQ%3D%3D?line=32'>33</a>     }
#      <a href='vscode-notebook-cell:/c%3A/Users/vbarbier/MESR/bso-coverage/1_openalex_database.ipynb#X12sZmlsZQ%3D%3D?line=33'>34</a>     df = pd.json_normalize(data)
#      <a href='vscode-notebook-cell:/c%3A/Users/vbarbier/MESR/bso-coverage/1_openalex_database.ipynb#X12sZmlsZQ%3D%3D?line=34'>35</a>     # print("data", data)
#      <a href='vscode-notebook-cell:/c%3A/Users/vbarbier/MESR/bso-coverage/1_openalex_database.ipynb#X12sZmlsZQ%3D%3D?line=35'>36</a>
#      <a href='vscode-notebook-cell:/c%3A/Users/vbarbier/MESR/bso-coverage/1_openalex_database.ipynb#X12sZmlsZQ%3D%3D?line=36'>37</a>     # Add publication to duckdb
#
# File c:\Users\vbarbier\MESR\bso-coverage\bso_coverage_tools.py:466, in analyse_from_openalex_work(alex_work, cli, as_pandas)
#     463 doi = alex_work["doi"].removeprefix(ALEX_DOI_PREFIX)
#     465 # Analyse work
# --> 466 result = analyse_work(doi, alex_work=alex_work, cli=cli, as_pandas=as_pandas)
#     468 return result
#
# File c:\Users\vbarbier\MESR\bso-coverage\bso_coverage_tools.py:351, in analyse_work(doi, alex_work, cli, as_pandas)
#     349 if not cli:
#     350     conn = swift_connection()
# --> 351     auth = conn.get_auth()
#     353 # Parsing fr
#     354 if state == State.UNDEFINED:
#
# File c:\Users\vbarbier\AppData\Local\Programs\Python\Python311\Lib\site-packages\swiftclient\client.py:1680, in Connection.get_auth(self)
#    1679 def get_auth(self):
# -> 1680     self.url, self.token = get_auth(self.authurl, self.user, self.key,
#    1681                                     session=self.session, snet=self.snet,
#    1682                                     auth_version=self.auth_version,
#    1683                                     os_options=self.os_options,
#    1684                                     cacert=self.cacert,
#    1685                                     insecure=self.insecure,
#    1686                                     cert=self.cert,
#    1687                                     cert_key=self.cert_key,
#    1688                                     timeout=self.timeout)
#    1689     return self.url, self.token
#
# File c:\Users\vbarbier\AppData\Local\Programs\Python\Python311\Lib\site-packages\swiftclient\client.py:727, in get_auth(auth_url, user, key, **kwargs)
#     724             raise ClientException('No tenant specified')
#     725         raise ClientException('No project name or project id specified.')
# --> 727     storage_url, token = get_auth_keystone(auth_url, user,
#     728                                            key, os_options,
#     729                                            cacert=cacert,
#     730                                            insecure=insecure,
#     731                                            cert=cert,
#     732                                            cert_key=cert_key,
#     733                                            timeout=timeout,
#     734                                            auth_version=auth_version)
#     735 else:
#     736     raise ClientException('Unknown auth_version %s specified and no '
#     737                           'session found.' % auth_version)
#
# File c:\Users\vbarbier\AppData\Local\Programs\Python\Python311\Lib\site-packages\swiftclient\client.py:644, in get_auth_keystone(auth_url, user, key, os_options, **kwargs)
#     642     raise ClientException(msg)
#     643 except ksexceptions.AuthorizationFailure as err:
# --> 644     raise ClientException('Authorization Failure. %s' % err)
#     645 service_type = os_options.get('service_type') or 'object-store'
#     646 endpoint_type = os_options.get('endpoint_type') or 'publicURL'
#
# ClientException: Authorization Failure. Authorization failed: HTTP Client Error (HTTP 429)

# %%
with duckdb.connect("bso_coverage.db") as con:
    con.table("openalex_fr").show()
# Out:
# ┌──────────────────────┬──────────────────────┬──────────────────────┬───┬──────────────────────┬──────────────────────┐
# │          id          │         doi          │     coverage.doi     │ … │ coverage.last_error  │ coverage.last_erro…  │
# │       varchar        │       varchar        │       varchar        │   │       varchar        │      varchar[]       │
# ├──────────────────────┼──────────────────────┼──────────────────────┼───┼──────────────────────┼──────────────────────┤
# │ https://openalex.o…  │ https://doi.org/10…  │ 10.1038/nmeth.2019   │ … │ DOI_EARLY_PUBLICAT…  │ [publication_year,…  │
# │ https://openalex.o…  │ https://doi.org/10…  │ 10.1038/s41592-019…  │ … │ MISMATCH_TYPE        │ [journal-article, …  │
# │ https://openalex.o…  │ https://doi.org/10…  │ 10.1136/bmj.l4898    │ … │ MISMATCH_TYPE        │ [journal-article, …  │
# │ https://openalex.o…  │ https://doi.org/10…  │ 10.1051/0004-6361/…  │ … │ MISMATCH_TYPE        │ [journal-article, …  │
# │ https://openalex.o…  │ https://doi.org/10…  │ 10.1080/20013078.2…  │ … │ MISMATCH_TYPE        │ [journal-article, …  │
# │ https://openalex.o…  │ https://doi.org/10…  │ 10.1016/s1474-4422…  │ … │ MISMATCH_TYPE        │ [journal-article, …  │
# │ https://openalex.o…  │ https://doi.org/10…  │ 10.1016/s0140-6736…  │ … │ MISMATCH_TYPE        │ [journal-article, …  │
# │ https://openalex.o…  │ https://doi.org/10…  │ 10.1016/j.ijantimi…  │ … │ MISMATCH_TYPE        │ [journal-article, …  │
# │ https://openalex.o…  │ https://doi.org/10…  │ 10.1038/s41418-017…  │ … │ MISMATCH_TYPE        │ [journal-article, …  │
# │ https://openalex.o…  │ https://doi.org/10…  │ 10.1107/s205979831…  │ … │ MISMATCH_TYPE        │ [journal-article, …  │
# │          ·           │          ·           │          ·           │ · │       ·              │          ·           │
# │          ·           │          ·           │          ·           │ · │       ·              │          ·           │
# │          ·           │          ·           │          ·           │ · │       ·              │          ·           │
# │ https://openalex.o…  │ https://doi.org/10…  │ 10.1146/annurev-fl…  │ … │ MISMATCH_TYPE        │ [journal-article, …  │
# │ https://openalex.o…  │ https://doi.org/10…  │ 10.1056/nejmoa2028…  │ … │ NOT_PARSED_FR        │ NULL                 │
# │ https://openalex.o…  │ https://doi.org/10…  │ 10.1016/s1470-2045…  │ … │ MISMATCH_TYPE        │ [journal-article, …  │
# │ https://openalex.o…  │ https://doi.org/10…  │ 10.1093/annonc/mdz…  │ … │ MISMATCH_TYPE        │ [journal-article, …  │
# │ https://openalex.o…  │ https://doi.org/10…  │ 10.1126/science.aa…  │ … │ MISMATCH_TYPE        │ [journal-article, …  │
# │ https://openalex.o…  │ https://doi.org/10…  │ 10.1038/s41564-018…  │ … │ MISMATCH_TYPE        │ [journal-article, …  │
# │ https://openalex.o…  │ https://doi.org/10…  │ 10.1038/s41422-020…  │ … │ MISMATCH_TYPE        │ [journal-article, …  │
# │ https://openalex.o…  │ https://doi.org/10…  │ 10.1056/nejmoa2207…  │ … │ MISMATCH_TYPE        │ [journal-article, …  │
# │ https://openalex.o…  │ https://doi.org/10…  │ 10.1016/j.stem.201…  │ … │ MISMATCH_TYPE        │ [journal-article, …  │
# │ https://openalex.o…  │ NULL                 │ NULL                 │ … │ NULL                 │ NULL                 │
# ├──────────────────────┴──────────────────────┴──────────────────────┴───┴──────────────────────┴──────────────────────┤
# │ 83 rows (20 shown)                                                                               6 columns (5 shown) │
# └──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
    with duckdb.connect("bso_coverage.db") as con:
        con.execute("CREATE TABLE openalex_coverage AS SELECT * FROM 'data/part_000/part_000.jsonl'")
        con.table("openalex_coverage").show()
